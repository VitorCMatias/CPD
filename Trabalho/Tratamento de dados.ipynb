# %% [markdown]
# # Limpeza de Dados

# %% [markdown]
# #### Lendo o database e imprimindo as colunas disponiveis

# %%
import pandas as pd
import xlrd

df = pd.read_excel('Hot Stuff.xlsx')

# %%
#colunas disponiveis
print(df.columns)
# Out:
# Index(['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID',
#        'Instance', 'Previous Week Position', 'Peak Position',
#        'Weeks on Chart'],
#       dtype='object')

# %% [markdown]
# #### Testando como encontrar entradas de datas especificas

# %%
#Comparando um digito apenas com o inteiro especificado
#Celula de teste
for i in range(5):
    if (df['WeekID'][i][0] == '1'):
        print(df['WeekID'][i].split())
# Out:
# ['1990-05-05']
# ['1990-05-12']
# ['1990-05-19']
# ['1990-05-26']
# ['1990-06-02']

# %% [markdown]
# #### Calculando o quão popular foi uma música e qual a popularidade máxima atingida pela mesma e salvando essa e outras informações em um dicionario (Para se livrar das informações "inuteis que estão na .xlsx)

# %%
#esta celula calcula o quao popular foi uma musica no mes especificado (Maio de 1990) atribuindo um sistema de pontos baseado em que posicao ela ficou no top 100 em cada semana do mês
#vai contar o quao popular foi a musica no ano atribuindo pontos a quantas semanas ela ficou entre as mais tocadas
contador = {}

#testando se o char especificado esta na entrada atual
#pode ser usado para identificar anos diferentes
counter = 0
for i in range(len(df)):
    if '1990-05' in df['WeekID'][i]: #filtra todas as entradas por ano E mes nesse caso (Maio de 1990)
        if(df['SongID'][i] in contador): #testa se a musica ja esta no dicionario (ja foi computada)
            contador[df['SongID'][i]]['Pontos'] += (101 - df['Week Position'][i])
        else: #cai aqui se ainda nao foi computada
            contador[df['SongID'][i]] = {}
            contador[df['SongID'][i]]['Artista'] = df['Performer'][i]
            contador[df['SongID'][i]]['Titulo'] = df['Song'][i]
            contador[df['SongID'][i]]['Pontos'] = (101 - df['Week Position'][i])
            #A medida 'Peak' nao eh a posicao exata que ela atingiu mas os "pontos maximos" ganhos em uma semana (de 1 a 100)
            contador[df['SongID'][i]]['Peak'] = (101 - df['Peak Position'][i]) #salva qual foi a maior posicao alcançada pela musica (usada para criterios de desempate)
            contador[df['SongID'][i]]['Semanas'] = df['Weeks on Chart'][i] #Terceiro criterio de desempate

# %%
for x in contador:
    print ('SongID: ', x)
    for y in contador[x]:
        print (y,':',contador[x][y])
    print(" ")
# Out:
# SongID:  "B" GirlsYoung And Restless
# Artista : Young And Restless
# Titulo : "B" Girls
# Pontos : 114
# Peak : 47
# Semanas : 15
#
# SongID:  A Little LoveCorey Hart
# Artista : Corey Hart
# Titulo : A Little Love
# Pontos : 96
# Peak : 64
# Semanas : 11
#
# SongID:  All Around The WorldLisa Stansfield
# Artista : Lisa Stansfield
# Titulo : All Around The World
# Pontos : 329
# Peak : 98
# Semanas : 22
#
# SongID:  All I Wanna Do Is Make Love To YouHeart
# Artista : Heart
# Titulo : All I Wanna Do Is Make Love To You
# Pontos : 390
# Peak : 99
# Semanas : 20
#
# SongID:  All My LifeLinda Ronstadt (Featuring Aaron Neville)
# Artista : Linda Ronstadt (Featuring Aaron Neville)
# Titulo : All My Life
# Pontos : 66
# Peak : 90
# Semanas : 15
#
# SongID:  All That Glitters Isn't GoldThe Cover Girls
# Artista : The Cover Girls
# Titulo : All That Glitters Isn't Gold
# Pontos : 182
# Peak : 52
# Semanas : 12
#
# SongID:  AlrightJanet Jackson
# Artista : Janet Jackson
# Titulo : Alright
# Pontos : 375
# Peak : 97
# Semanas : 16
#
# SongID:  Always And ForeverWhistle
# Artista : Whistle
# Titulo : Always And Forever
# Pontos : 231
# Peak : 66
# Semanas : 15
#
# SongID:  Baby, It's TonightJude Cole
# Artista : Jude Cole
# Titulo : Baby, It's Tonight
# Pontos : 286
# Peak : 85
# Semanas : 18
#
# SongID:  Bad Of The HeartGeorge LaMond
# Artista : George LaMond
# Titulo : Bad Of The Heart
# Pontos : 76
# Peak : 76
# Semanas : 17
#
# SongID:  Black VelvetAlannah Myles
# Artista : Alannah Myles
# Titulo : Black Velvet
# Pontos : 255
# Peak : 100
# Semanas : 24
#
# SongID:  Blues Before And AfterThe Smithereens
# Artista : The Smithereens
# Titulo : Blues Before And After
# Pontos : 11
# Peak : 7
# Semanas : 2
#
# SongID:  Bounce BackAlisha
# Artista : Alisha
# Titulo : Bounce Back
# Pontos : 6
# Peak : 47
# Semanas : 8
#
# SongID:  Children Of The NightRichard Marx
# Artista : Richard Marx
# Titulo : Children Of The Night
# Pontos : 270
# Peak : 88
# Semanas : 15
#
# SongID:  Club At The End Of The StreetElton John
# Artista : Elton John
# Titulo : Club At The End Of The Street
# Pontos : 134
# Peak : 73
# Semanas : 16
#
# SongID:  C'mon And Get My LoveD-Mob Introducing Cathy Dennis
# Artista : D-Mob Introducing Cathy Dennis
# Titulo : C'mon And Get My Love
# Pontos : 3
# Peak : 91
# Semanas : 21
#
# SongID:  Coming Of AgeDamn Yankees
# Artista : Damn Yankees
# Titulo : Coming Of Age
# Pontos : 156
# Peak : 41
# Semanas : 12
#
# SongID:  Counting The DaysJoey Kid
# Artista : Joey Kid
# Titulo : Counting The Days
# Pontos : 34
# Peak : 31
# Semanas : 12
#
# SongID:  Cradle Of Love (From "Ford Fairlane")Billy Idol
# Artista : Billy Idol
# Titulo : Cradle Of Love (From "Ford Fairlane")
# Pontos : 142
# Peak : 99
# Semanas : 24
#
# SongID:  Cruising For BruisingBasia
# Artista : Basia
# Titulo : Cruising For Bruising
# Pontos : 257
# Peak : 72
# Semanas : 12
#
# SongID:  Cuts You UpPeter Murphy
# Artista : Peter Murphy
# Titulo : Cuts You Up
# Pontos : 101
# Peak : 46
# Semanas : 9
#
# SongID:  DangerousRoxette
# Artista : Roxette
# Titulo : Dangerous
# Pontos : 11
# Peak : 99
# Semanas : 21
#
# SongID:  Dare To Fall In LoveBrent Bourgeois
# Artista : Brent Bourgeois
# Titulo : Dare To Fall In Love
# Pontos : 183
# Peak : 69
# Semanas : 13
#
# SongID:  Deadbeat ClubThe B-52s
# Artista : The B-52s
# Titulo : Deadbeat Club
# Pontos : 229
# Peak : 71
# Semanas : 11
#
# SongID:  Do You Remember?Phil Collins
# Artista : Phil Collins
# Titulo : Do You Remember?
# Pontos : 283
# Peak : 97
# Semanas : 19
#
# SongID:  Don't Wanna Fall In LoveJane Child
# Artista : Jane Child
# Titulo : Don't Wanna Fall In Love
# Pontos : 344
# Peak : 99
# Semanas : 21
#
# SongID:  Doubleback (From "Back To The Future Part III")ZZ Top
# Artista : ZZ Top
# Titulo : Doubleback (From "Back To The Future Part III")
# Pontos : 40
# Peak : 51
# Semanas : 11
#
# SongID:  Drag My Bad Name DownThe 4 Of Us
# Artista : The 4 Of Us
# Titulo : Drag My Bad Name Down
# Pontos : 44
# Peak : 24
# Semanas : 5
#
# SongID:  Dub Be Good To MeBeats International
# Artista : Beats International
# Titulo : Dub Be Good To Me
# Pontos : 33
# Peak : 25
# Semanas : 5
#
# SongID:  Enjoy The SilenceDepeche Mode
# Artista : Depeche Mode
# Titulo : Enjoy The Silence
# Pontos : 231
# Peak : 93
# Semanas : 24
#
# SongID:  EscapadeJanet Jackson
# Artista : Janet Jackson
# Titulo : Escapade
# Pontos : 32
# Peak : 100
# Semanas : 17
#
# SongID:  ExpressionSalt-N-Pepa
# Artista : Salt-N-Pepa
# Titulo : Expression
# Pontos : 291
# Peak : 75
# Semanas : 21
#
# SongID:  ForeverKISS
# Artista : KISS
# Titulo : Forever
# Pontos : 158
# Peak : 93
# Semanas : 17
#
# SongID:  Get A LifeSoul II Soul
# Artista : Soul II Soul
# Titulo : Get A Life
# Pontos : 160
# Peak : 47
# Semanas : 11
#
# SongID:  Get Up! (Before The Night Is Over)Technotronic
# Artista : Technotronic
# Titulo : Get Up! (Before The Night Is Over)
# Pontos : 194
# Peak : 94
# Semanas : 20
#
# SongID:  Getting Away With ItElectronic
# Artista : Electronic
# Titulo : Getting Away With It
# Pontos : 241
# Peak : 63
# Semanas : 12
#
# SongID:  Girls Nite OutTyler Collins
# Artista : Tyler Collins
# Titulo : Girls Nite Out
# Pontos : 151
# Peak : 95
# Semanas : 21
#
# SongID:  Got To Tell Me SomethingAna
# Artista : Ana
# Titulo : Got To Tell Me Something
# Pontos : 29
# Peak : 35
# Semanas : 7
#
# SongID:  Have A HeartBonnie Raitt
# Artista : Bonnie Raitt
# Titulo : Have A Heart
# Pontos : 1
# Peak : 52
# Semanas : 9
#
# SongID:  Heart Of StoneCher
# Artista : Cher
# Titulo : Heart Of Stone
# Pontos : 36
# Peak : 81
# Semanas : 14
#
# SongID:  HeartbeatSeduction
# Artista : Seduction
# Titulo : Heartbeat
# Pontos : 264
# Peak : 88
# Semanas : 16
#
# SongID:  Heaven Is A 4 Letter WordBad English
# Artista : Bad English
# Titulo : Heaven Is A 4 Letter Word
# Pontos : 86
# Peak : 35
# Semanas : 9
#
# SongID:  Here And NowLuther Vandross
# Artista : Luther Vandross
# Titulo : Here And Now
# Pontos : 270
# Peak : 95
# Semanas : 27
#
# SongID:  Here We AreGloria Estefan
# Artista : Gloria Estefan
# Titulo : Here We Are
# Pontos : 5
# Peak : 95
# Semanas : 21
#
# SongID:  Hide And SeekPajama Party
# Artista : Pajama Party
# Titulo : Hide And Seek
# Pontos : 12
# Peak : 28
# Semanas : 10
#
# SongID:  Hold OnEn Vogue
# Artista : En Vogue
# Titulo : Hold On
# Pontos : 269
# Peak : 99
# Semanas : 25
#
# SongID:  Hold OnWilson Phillips
# Artista : Wilson Phillips
# Titulo : Hold On
# Pontos : 378
# Peak : 100
# Semanas : 25
#
# SongID:  House Of PainFaster Pussycat
# Artista : Faster Pussycat
# Titulo : House Of Pain
# Pontos : 282
# Peak : 73
# Semanas : 21
#
# SongID:  How 'Bout Us (From "True Love")Grayson Hugh & Betty Wright
# Artista : Grayson Hugh & Betty Wright
# Titulo : How 'Bout Us (From "True Love")
# Pontos : 37
# Peak : 34
# Semanas : 7
#
# SongID:  How Can We Be LoversMichael Bolton
# Artista : Michael Bolton
# Titulo : How Can We Be Lovers
# Pontos : 365
# Peak : 98
# Semanas : 18
#
# SongID:  Hurting Kind (I've Got My Eyes On You)Robert Plant
# Artista : Robert Plant
# Titulo : Hurting Kind (I've Got My Eyes On You)
# Pontos : 72
# Peak : 55
# Semanas : 10
#
# SongID:  I Wanna Be RichCalloway
# Artista : Calloway
# Titulo : I Wanna Be Rich
# Pontos : 379
# Peak : 99
# Semanas : 23
#
# SongID:  I Wish It Would Rain DownPhil Collins
# Artista : Phil Collins
# Titulo : I Wish It Would Rain Down
# Pontos : 129
# Peak : 98
# Semanas : 17
#
# SongID:  If U Were MineThe U-Krew
# Artista : The U-Krew
# Titulo : If U Were Mine
# Pontos : 203
# Peak : 77
# Semanas : 22
#
# SongID:  I'll Be Your EverythingTommy Page
# Artista : Tommy Page
# Titulo : I'll Be Your Everything
# Pontos : 280
# Peak : 100
# Semanas : 18
#
# SongID:  I'll Be Your ShelterTaylor Dayne
# Artista : Taylor Dayne
# Titulo : I'll Be Your Shelter
# Pontos : 246
# Peak : 97
# Semanas : 18
#
# SongID:  I'll See You In My DreamsGiant
# Artista : Giant
# Titulo : I'll See You In My Dreams
# Pontos : 274
# Peak : 81
# Semanas : 20
#
# SongID:  It Must Have Been Love (From "Pretty Woman")Roxette
# Artista : Roxette
# Titulo : It Must Have Been Love (From "Pretty Woman")
# Pontos : 349
# Peak : 100
# Semanas : 25
#
# SongID:  Jealous AgainThe Black Crowes
# Artista : The Black Crowes
# Titulo : Jealous Again
# Pontos : 43
# Peak : 26
# Semanas : 9
#
# SongID:  Just A FriendBiz Markie
# Artista : Biz Markie
# Titulo : Just A Friend
# Pontos : 204
# Peak : 92
# Semanas : 22
#
# SongID:  King Of Wishful Thinking (From "Pretty Woman")Go West
# Artista : Go West
# Titulo : King Of Wishful Thinking (From "Pretty Woman")
# Pontos : 28
# Peak : 93
# Semanas : 24
#
# SongID:  Kiss This Thing GoodbyeDel Amitri
# Artista : Del Amitri
# Titulo : Kiss This Thing Goodbye
# Pontos : 50
# Peak : 66
# Semanas : 11
#
# SongID:  LambadaKaoma
# Artista : Kaoma
# Titulo : Lambada
# Pontos : 24
# Peak : 55
# Semanas : 12
#
# SongID:  Love ChildSweet Sensation
# Artista : Sweet Sensation
# Titulo : Love Child
# Pontos : 347
# Peak : 88
# Semanas : 15
#
# SongID:  Love IsAlannah Myles
# Artista : Alannah Myles
# Titulo : Love Is
# Pontos : 130
# Peak : 65
# Semanas : 13
#
# SongID:  Love Me For LifeStevie B
# Artista : Stevie B
# Titulo : Love Me For Life
# Pontos : 2
# Peak : 72
# Semanas : 14
#
# SongID:  Love Will Lead You BackTaylor Dayne
# Artista : Taylor Dayne
# Titulo : Love Will Lead You Back
# Pontos : 229
# Peak : 100
# Semanas : 20
#
# SongID:  Make It Like It WasRegina Belle
# Artista : Regina Belle
# Titulo : Make It Like It Was
# Pontos : 8
# Peak : 58
# Semanas : 11
#
# SongID:  MentirosaMellow Man Ace
# Artista : Mellow Man Ace
# Titulo : Mentirosa
# Pontos : 82
# Peak : 87
# Semanas : 24
#
# SongID:  Moonlight On WaterLaura Branigan
# Artista : Laura Branigan
# Titulo : Moonlight On Water
# Pontos : 98
# Peak : 42
# Semanas : 9
#
# SongID:  NicetyMichel'le
# Artista : Michel'le
# Titulo : Nicety
# Pontos : 217
# Peak : 72
# Semanas : 16
#
# SongID:  Nick Of TimeBonnie Raitt
# Artista : Bonnie Raitt
# Titulo : Nick Of Time
# Pontos : 16
# Peak : 9
# Semanas : 3
#
# SongID:  No More LiesMichel'le
# Artista : Michel'le
# Titulo : No More Lies
# Pontos : 137
# Peak : 94
# Semanas : 29
#
# SongID:  Nothing Compares 2 USinead O'Connor
# Artista : Sinead O'Connor
# Titulo : Nothing Compares 2 U
# Pontos : 397
# Peak : 100
# Semanas : 21
#
# SongID:  Notice MeNikki
# Artista : Nikki
# Titulo : Notice Me
# Pontos : 190
# Peak : 80
# Semanas : 15
#
# SongID:  Only My Heart Talkin'Alice Cooper
# Artista : Alice Cooper
# Titulo : Only My Heart Talkin'
# Pontos : 20
# Peak : 12
# Semanas : 3
#
# SongID:  Ooh La La (I Can't Get Over You)Perfect Gentlemen
# Artista : Perfect Gentlemen
# Titulo : Ooh La La (I Can't Get Over You)
# Pontos : 324
# Peak : 91
# Semanas : 16
#
# SongID:  Opposites AttractPaula Abdul (Duet With The Wild Pair)
# Artista : Paula Abdul (Duet With The Wild Pair)
# Titulo : Opposites Attract
# Pontos : 43
# Peak : 100
# Semanas : 23
#
# SongID:  Oye Mi Canto (Hear My Voice)Gloria Estefan
# Artista : Gloria Estefan
# Titulo : Oye Mi Canto (Hear My Voice)
# Pontos : 111
# Peak : 53
# Semanas : 7
#
# SongID:  Pictures Of YouThe Cure
# Artista : The Cure
# Titulo : Pictures Of You
# Pontos : 110
# Peak : 30
# Semanas : 8
#
# SongID:  PoisonBell Biv DeVoe
# Artista : Bell Biv DeVoe
# Titulo : Poison
# Pontos : 362
# Peak : 98
# Semanas : 22
#
# SongID:  PureLightning Seeds
# Artista : Lightning Seeds
# Titulo : Pure
# Pontos : 29
# Peak : 70
# Semanas : 15
#
# SongID:  Ready Or NotAfter 7
# Artista : After 7
# Titulo : Ready Or Not
# Pontos : 313
# Peak : 94
# Semanas : 21
#
# SongID:  RoamThe B-52s
# Artista : The B-52s
# Titulo : Roam
# Pontos : 4
# Peak : 98
# Semanas : 20
#
# SongID:  Room At The TopAdam Ant
# Artista : Adam Ant
# Titulo : Room At The Top
# Pontos : 325
# Peak : 84
# Semanas : 16
#
# SongID:  Rub You The Right WayJohnny Gill
# Artista : Johnny Gill
# Titulo : Rub You The Right Way
# Pontos : 175
# Peak : 98
# Semanas : 23
#
# SongID:  SacrificeElton John
# Artista : Elton John
# Titulo : Sacrifice
# Pontos : 15
# Peak : 83
# Semanas : 17
#
# SongID:  Save MeFleetwood Mac
# Artista : Fleetwood Mac
# Titulo : Save Me
# Pontos : 252
# Peak : 68
# Semanas : 11
#
# SongID:  Sending All My LoveLinear
# Artista : Linear
# Titulo : Sending All My Love
# Pontos : 371
# Peak : 96
# Semanas : 27
#
# SongID:  ShakeAndrew Ridgeley
# Artista : Andrew Ridgeley
# Titulo : Shake
# Pontos : 62
# Peak : 24
# Semanas : 6
#
# SongID:  She Ain't Worth ItGlenn Medeiros Featuring Bobby Brown
# Artista : Glenn Medeiros Featuring Bobby Brown
# Titulo : She Ain't Worth It
# Pontos : 114
# Peak : 100
# Semanas : 18
#
# SongID:  Show MeHoward Hewett
# Artista : Howard Hewett
# Titulo : Show Me
# Pontos : 17
# Peak : 39
# Semanas : 7
#
# SongID:  Sittin' In The Lap Of LuxuryLouie Louie
# Artista : Louie Louie
# Titulo : Sittin' In The Lap Of Luxury
# Pontos : 203
# Peak : 82
# Semanas : 16
#
# SongID:  Spin That WheelHi Tek 3 Featuring Ya Kid K
# Artista : Hi Tek 3 Featuring Ya Kid K
# Titulo : Spin That Wheel
# Pontos : 68
# Peak : 32
# Semanas : 7
#
# SongID:  Step By StepNew Kids On The Block
# Artista : New Kids On The Block
# Titulo : Step By Step
# Pontos : 74
# Peak : 100
# Semanas : 15
#
# SongID:  That's The Way Of The WorldD-Mob With Cathy Dennis
# Artista : D-Mob With Cathy Dennis
# Titulo : That's The Way Of The World
# Pontos : 152
# Peak : 42
# Semanas : 9
#
# SongID:  The Ballad Of JayneL.A. Guns
# Artista : L.A. Guns
# Titulo : The Ballad Of Jayne
# Pontos : 143
# Peak : 68
# Semanas : 22
#
# SongID:  The Downeaster "Alexa"Billy Joel
# Artista : Billy Joel
# Titulo : The Downeaster "Alexa"
# Pontos : 123
# Peak : 44
# Semanas : 8
#
# SongID:  The Heart Of The MatterDon Henley
# Artista : Don Henley
# Titulo : The Heart Of The Matter
# Pontos : 252
# Peak : 80
# Semanas : 21
#
# SongID:  The Humpty DanceDigital Underground
# Artista : Digital Underground
# Titulo : The Humpty Dance
# Pontos : 334
# Peak : 90
# Semanas : 23
#
# SongID:  The PowerSnap!
# Artista : Snap!
# Titulo : The Power
# Pontos : 97
# Peak : 99
# Semanas : 22
#
# SongID:  The Secret GardenQuincy Jones
# Artista : Quincy Jones
# Titulo : The Secret Garden
# Pontos : 120
# Peak : 70
# Semanas : 13
#
# SongID:  The Way It IsTesla
# Artista : Tesla
# Titulo : The Way It Is
# Pontos : 46
# Peak : 46
# Semanas : 12
#
# SongID:  This & ThatMichael Penn
# Artista : Michael Penn
# Titulo : This & That
# Pontos : 131
# Peak : 48
# Semanas : 8
#
# SongID:  This Old Heart Of MineRod Stewart With Ronald Isley
# Artista : Rod Stewart With Ronald Isley
# Titulo : This Old Heart Of Mine
# Pontos : 354
# Peak : 91
# Semanas : 16
#
# SongID:  Time After TimeTimmy T.
# Artista : Timmy T.
# Titulo : Time After Time
# Pontos : 195
# Peak : 61
# Semanas : 17
#
# SongID:  Tomorrow (A Better You, Better Me)Quincy Jones With Tevin Campbell
# Artista : Quincy Jones With Tevin Campbell
# Titulo : Tomorrow (A Better You, Better Me)
# Pontos : 13
# Peak : 26
# Semanas : 5
#
# SongID:  Try To Find MeGorky Park
# Artista : Gorky Park
# Titulo : Try To Find Me
# Pontos : 62
# Peak : 20
# Semanas : 6
#
# SongID:  Turtle PowerPartners In Kryme
# Artista : Partners In Kryme
# Titulo : Turtle Power
# Pontos : 292
# Peak : 88
# Semanas : 16
#
# SongID:  U Can't Touch ThisM.C. Hammer
# Artista : M.C. Hammer
# Titulo : U Can't Touch This
# Pontos : 338
# Peak : 93
# Semanas : 17
#
# SongID:  Up All NightSlaughter
# Artista : Slaughter
# Titulo : Up All Night
# Pontos : 169
# Peak : 74
# Semanas : 14
#
# SongID:  VogueMadonna
# Artista : Madonna
# Titulo : Vogue
# Pontos : 396
# Peak : 100
# Semanas : 24
#
# SongID:  What It TakesAerosmith
# Artista : Aerosmith
# Titulo : What It Takes
# Pontos : 356
# Peak : 92
# Semanas : 17
#
# SongID:  When I Dream Of YouTommy Page
# Artista : Tommy Page
# Titulo : When I Dream Of You
# Pontos : 82
# Peak : 59
# Semanas : 10
#
# SongID:  When I'm Back On My Feet AgainMichael Bolton
# Artista : Michael Bolton
# Titulo : When I'm Back On My Feet Again
# Pontos : 27
# Peak : 94
# Semanas : 19
#
# SongID:  When Something Is Wrong With My BabyLinda Ronstadt (Featuring Aaron Neville)
# Artista : Linda Ronstadt (Featuring Aaron Neville)
# Titulo : When Something Is Wrong With My Baby
# Pontos : 34
# Peak : 23
# Semanas : 6
#
# SongID:  Whip AppealBabyface
# Artista : Babyface
# Titulo : Whip Appeal
# Pontos : 333
# Peak : 95
# Semanas : 18
#
# SongID:  Whole Wide World (From "True Love")A'me Lorain
# Artista : A'me Lorain
# Titulo : Whole Wide World (From "True Love")
# Pontos : 211
# Peak : 92
# Semanas : 20
#
# SongID:  Without YouMotley Crue
# Artista : Motley Crue
# Titulo : Without You
# Pontos : 298
# Peak : 93
# Semanas : 17
#
# SongID:  You Can't Deny ItLisa Stansfield
# Artista : Lisa Stansfield
# Titulo : You Can't Deny It
# Pontos : 20
# Peak : 87
# Semanas : 14
#
# SongID:  Your Baby Never Looked Good In BlueExpose
# Artista : Expose
# Titulo : Your Baby Never Looked Good In Blue
# Pontos : 323
# Peak : 84
# Semanas : 16

# %% [markdown]
# #### Ordenando o dicionario pelas músicas mais populares e usando a popularidade máxima atingida em uma semana como critério de desempate

# %%
items = sorted(contador.items(), key = lambda tup: (tup[1]["Pontos"], tup[1]["Peak"], tup[1]["Semanas"]), reverse=True)

# %% [markdown]
# #### Imprimindo as 15 primeiras para testar

# %%
#1 deve sempre se manter fixo enquanto 
for i in range(5): #varre as 5 mais tocadas
    for y in items[i][1]: #varre as diferentes categorias do dicionario (artista, titulo, pontos)
        print(items[i][1][y])
    print('')
# Out:
# Sinead O'Connor
# Nothing Compares 2 U
# 397
# 100
# 21
#
# Madonna
# Vogue
# 396
# 100
# 24
#
# Heart
# All I Wanna Do Is Make Love To You
# 390
# 99
# 20
#
# Calloway
# I Wanna Be Rich
# 379
# 99
# 23
#
# Wilson Phillips
# Hold On
# 378
# 100
# 25

# %% [markdown]
# #### Cria um dicionario mais organizado com as 100 mais tocadas no período especificado

# %%
#armazena as primeiras 100 entradas em um dicionário mais organizado
top = [dict() for x in range(100)] #cria uma lista de 100 dicionarios

for i in range(len(top)):
    for y in items[i][1]:
        top[i][y] = items[i][1][y]

# %%
for x in range(100):
    print(top[x]['Titulo'], ':', top[x]['Pontos'])
# Out:
# Nothing Compares 2 U : 397
# Vogue : 396
# All I Wanna Do Is Make Love To You : 390
# I Wanna Be Rich : 379
# Hold On : 378
# Alright : 375
# Sending All My Love : 371
# How Can We Be Lovers : 365
# Poison : 362
# What It Takes : 356
# This Old Heart Of Mine : 354
# It Must Have Been Love (From "Pretty Woman") : 349
# Love Child : 347
# Don't Wanna Fall In Love : 344
# U Can't Touch This : 338
# The Humpty Dance : 334
# Whip Appeal : 333
# All Around The World : 329
# Room At The Top : 325
# Ooh La La (I Can't Get Over You) : 324
# Your Baby Never Looked Good In Blue : 323
# Ready Or Not : 313
# Without You : 298
# Turtle Power : 292
# Expression : 291
# Baby, It's Tonight : 286
# Do You Remember? : 283
# House Of Pain : 282
# I'll Be Your Everything : 280
# I'll See You In My Dreams : 274
# Here And Now : 270
# Children Of The Night : 270
# Hold On : 269
# Heartbeat : 264
# Cruising For Bruising : 257
# Black Velvet : 255
# The Heart Of The Matter : 252
# Save Me : 252
# I'll Be Your Shelter : 246
# Getting Away With It : 241
# Enjoy The Silence : 231
# Always And Forever : 231
# Love Will Lead You Back : 229
# Deadbeat Club : 229
# Nicety : 217
# Whole Wide World (From "True Love") : 211
# Just A Friend : 204
# Sittin' In The Lap Of Luxury : 203
# If U Were Mine : 203
# Time After Time : 195
# Get Up! (Before The Night Is Over) : 194
# Notice Me : 190
# Dare To Fall In Love : 183
# All That Glitters Isn't Gold : 182
# Rub You The Right Way : 175
# Up All Night : 169
# Get A Life : 160
# Forever : 158
# Coming Of Age : 156
# That's The Way Of The World : 152
# Girls Nite Out : 151
# The Ballad Of Jayne : 143
# Cradle Of Love (From "Ford Fairlane") : 142
# No More Lies : 137
# Club At The End Of The Street : 134
# This & That : 131
# Love Is : 130
# I Wish It Would Rain Down : 129
# The Downeaster "Alexa" : 123
# The Secret Garden : 120
# She Ain't Worth It : 114
# "B" Girls : 114
# Oye Mi Canto (Hear My Voice) : 111
# Pictures Of You : 110
# Cuts You Up : 101
# Moonlight On Water : 98
# The Power : 97
# A Little Love : 96
# Heaven Is A 4 Letter Word : 86
# Mentirosa : 82
# When I Dream Of You : 82
# Bad Of The Heart : 76
# Step By Step : 74
# Hurting Kind (I've Got My Eyes On You) : 72
# Spin That Wheel : 68
# All My Life : 66
# Shake : 62
# Try To Find Me : 62
# Kiss This Thing Goodbye : 50
# The Way It Is : 46
# Drag My Bad Name Down : 44
# Opposites Attract : 43
# Jealous Again : 43
# Doubleback (From "Back To The Future Part III") : 40
# How 'Bout Us (From "True Love") : 37
# Heart Of Stone : 36
# Counting The Days : 34
# When Something Is Wrong With My Baby : 34
# Dub Be Good To Me : 33
# Escapade : 32

# %% [markdown]
# #### Testando como escrever e ler de arquivos binarios
# ##### Mostra como guardar os arquivos binarios, eles devem ser estruturados e entao salvas desse jeito

# %%
import pickle #modulo usado para serializar dados para o arquivo binario
import os

filename = 'teste.bin'
fileBytes = []

if os.path.exists(filename): #confere se o arquivo existe
    print('ENTROU')
    with open(filename,'rb') as openfile:  #with automaticamente da um close() no final
        fileBytes = pickle.load(openfile)


newData = top[0:10] #Aqui vem a nova data que deve ser concatenada
        
fileBytes = fileBytes + newData #concatena o que ja tinha no arquivo binario com a nova data
with (open(filename, 'wb+')) as openfile: #abre o arquivo de teste no modo de leitura binaria 'wb' como openfile
    pickle.dump(fileBytes, openfile)

# %%
with (open('teste.bin', 'rb')) as openfile:
    leitura = pickle.load(openfile)
    
print(leitura)
# Out:
# [{'Artista': "Sinead O'Connor", 'Titulo': 'Nothing Compares 2 U', 'Pontos': 397, 'Peak': 100, 'Semanas': 21}, {'Artista': 'Madonna', 'Titulo': 'Vogue', 'Pontos': 396, 'Peak': 100, 'Semanas': 24}, {'Artista': 'Heart', 'Titulo': 'All I Wanna Do Is Make Love To You', 'Pontos': 390, 'Peak': 99, 'Semanas': 20}, {'Artista': 'Calloway', 'Titulo': 'I Wanna Be Rich', 'Pontos': 379, 'Peak': 99, 'Semanas': 23}, {'Artista': 'Wilson Phillips', 'Titulo': 'Hold On', 'Pontos': 378, 'Peak': 100, 'Semanas': 25}, {'Artista': 'Janet Jackson', 'Titulo': 'Alright', 'Pontos': 375, 'Peak': 97, 'Semanas': 16}, {'Artista': 'Linear', 'Titulo': 'Sending All My Love', 'Pontos': 371, 'Peak': 96, 'Semanas': 27}, {'Artista': 'Michael Bolton', 'Titulo': 'How Can We Be Lovers', 'Pontos': 365, 'Peak': 98, 'Semanas': 18}, {'Artista': 'Bell Biv DeVoe', 'Titulo': 'Poison', 'Pontos': 362, 'Peak': 98, 'Semanas': 22}, {'Artista': 'Aerosmith', 'Titulo': 'What It Takes', 'Pontos': 356, 'Peak': 92, 'Semanas': 17}]

# %% [markdown]
# #### Montar um arquivo binario com o top 100 de cada ano
