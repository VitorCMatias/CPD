# %% [markdown]
# # Limpeza de Dados

# %% [markdown]
# #### Lendo o database e imprimindo as colunas disponiveis

# %%
import pandas as pd
import xlrd

df = pd.read_excel('Hot Stuff.xlsx')

# %%
#colunas disponiveis
print(df.columns)
# Out:
# Index(['url', 'WeekID', 'Week Position', 'Song', 'Performer', 'SongID',
#        'Instance', 'Previous Week Position', 'Peak Position',
#        'Weeks on Chart'],
#       dtype='object')

# %% [markdown]
# #### Testando como encontrar entradas de datas especificas

# %%
#Comparando um digito apenas com o inteiro especificado
#Celula de teste
for i in range(5):
    if (df['WeekID'][i][0] == '1'):
        print(df['WeekID'][i].split())
# Out:
# ['1990-05-05']
# ['1990-05-12']
# ['1990-05-19']
# ['1990-05-26']
# ['1990-06-02']

# %% [markdown]
# #### Calculando o quão popular foi uma música e qual a popularidade máxima atingida pela mesma e salvando essa e outras informações em um dicionario (Para se livrar das informações "inuteis que estão na .xlsx)

# %%
#esta celula calcula o quao popular foi uma musica no mes especificado (Maio de 1990) atribuindo um sistema de pontos baseado em que posicao ela ficou no top 100 em cada semana do mês
#vai contar o quao popular foi a musica no ano atribuindo pontos a quantas semanas ela ficou entre as mais tocadas
contador = {}

#testando se o char especificado esta na entrada atual
#pode ser usado para identificar anos diferentes
ano = '2010'
mes = '10'
for i in range(len(df)):
    if (ano + '-' + mes + '-') in df['WeekID'][i]: #filtra todas as entradas por ano E mes nesse caso (Maio de 1990)
        if(df['SongID'][i] in contador): #testa se a musica ja esta no dicionario (ja foi computada)
            contador[df['SongID'][i]]['Pontos'] += (101 - df['Week Position'][i])
        else: #cai aqui se ainda nao foi computada
            contador[df['SongID'][i]] = {}
            contador[df['SongID'][i]]['Artista'] = df['Performer'][i]
            contador[df['SongID'][i]]['Titulo'] = df['Song'][i]
            contador[df['SongID'][i]]['Ano'] = ano
            contador[df['SongID'][i]]['Mes'] = mes
            contador[df['SongID'][i]]['Pontos'] = (101 - df['Week Position'][i])
            #A medida 'Peak' nao eh a posicao exata que ela atingiu mas os "pontos maximos" ganhos em uma semana (de 1 a 100)
            contador[df['SongID'][i]]['Peak'] = (101 - df['Peak Position'][i]) #salva qual foi a maior posicao alcançada pela musica (usada para criterios de desempate)
            contador[df['SongID'][i]]['Semanas'] = df['Weeks on Chart'][i] #Terceiro criterio de desempate

# %%
for x in contador:
    print ('SongID: ', x)
    for y in contador[x]:
        print (y,':',contador[x][y])
    print(" ")
# Out:
# SongID:  2012 (It Ain't The End)Jay Sean Featuring Nicki Minaj
# Artista : Jay Sean Featuring Nicki Minaj
# Titulo : 2012 (It Ain't The End)
# Ano : 2010
# Mes : 10
# Pontos : 331
# Peak : 70
# Semanas : 14
#
# SongID:  A Year Without RainSelena Gomez & The Scene
# Artista : Selena Gomez & The Scene
# Titulo : A Year Without Rain
# Ano : 2010
# Mes : 10
# Pontos : 114
# Peak : 66
# Semanas : 8
#
# SongID:  AirplanesB.o.B Featuring Hayley Williams
# Artista : B.o.B Featuring Hayley Williams
# Titulo : Airplanes
# Ano : 2010
# Mes : 10
# Pontos : 394
# Peak : 99
# Semanas : 30
#
# SongID:  All About TonightBlake Shelton
# Artista : Blake Shelton
# Titulo : All About Tonight
# Ano : 2010
# Mes : 10
# Pontos : 76
# Peak : 64
# Semanas : 19
#
# SongID:  All I Want Is YouMiguel Featuring J. Cole
# Artista : Miguel Featuring J. Cole
# Titulo : All I Want Is You
# Ano : 2010
# Mes : 10
# Pontos : 116
# Peak : 43
# Semanas : 14
#
# SongID:  All Over MeJosh Turner
# Artista : Josh Turner
# Titulo : All Over Me
# Ano : 2010
# Mes : 10
# Pontos : 199
# Peak : 42
# Semanas : 18
#
# SongID:  AngelAkon
# Artista : Akon
# Titulo : Angel
# Ano : 2010
# Mes : 10
# Pontos : 45
# Peak : 45
# Semanas : 10
#
# SongID:  AnimalNeon Trees
# Artista : Neon Trees
# Titulo : Animal
# Ano : 2010
# Mes : 10
# Pontos : 416
# Peak : 88
# Semanas : 36
#
# SongID:  Anything Like MeBrad Paisley
# Artista : Brad Paisley
# Titulo : Anything Like Me
# Ano : 2010
# Mes : 10
# Pontos : 143
# Peak : 53
# Semanas : 19
#
# SongID:  As She's Walking AwayZac Brown Band Featuring Alan Jackson
# Artista : Zac Brown Band Featuring Alan Jackson
# Titulo : As She's Walking Away
# Ano : 2010
# Mes : 10
# Pontos : 263
# Peak : 69
# Semanas : 20
#
# SongID:  Aston Martin MusicRick Ross Featuring Drake & Chrisette Michele
# Artista : Rick Ross Featuring Drake & Chrisette Michele
# Titulo : Aston Martin Music
# Ano : 2010
# Mes : 10
# Pontos : 40
# Peak : 71
# Semanas : 20
#
# SongID:  B.M.F. (Blowin' Money Fast)Rick Ross Featuring Styles P
# Artista : Rick Ross Featuring Styles P
# Titulo : B.M.F. (Blowin' Money Fast)
# Ano : 2010
# Mes : 10
# Pontos : 106
# Peak : 41
# Semanas : 16
#
# SongID:  Baby One More TimeGlee Cast
# Artista : Glee Cast
# Titulo : Baby One More Time
# Ano : 2010
# Mes : 10
# Pontos : 47
# Peak : 47
# Semanas : 1
#
# SongID:  Back To DecemberTaylor Swift
# Artista : Taylor Swift
# Titulo : Back To December
# Ano : 2010
# Mes : 10
# Pontos : 95
# Peak : 95
# Semanas : 20
#
# SongID:  Bill GatesLil Wayne
# Artista : Lil Wayne
# Titulo : Bill Gates
# Ano : 2010
# Mes : 10
# Pontos : 26
# Peak : 26
# Semanas : 1
#
# SongID:  BillionaireGlee Cast
# Artista : Glee Cast
# Titulo : Billionaire
# Ano : 2010
# Mes : 10
# Pontos : 73
# Peak : 73
# Semanas : 1
#
# SongID:  BillionaireTravie McCoy Featuring Bruno Mars
# Artista : Travie McCoy Featuring Bruno Mars
# Titulo : Billionaire
# Ano : 2010
# Mes : 10
# Pontos : 203
# Peak : 97
# Semanas : 27
#
# SongID:  BittersweetFantasia
# Artista : Fantasia
# Titulo : Bittersweet
# Ano : 2010
# Mes : 10
# Pontos : 25
# Peak : 27
# Semanas : 12
#
# SongID:  Black And YellowWiz Khalifa
# Artista : Wiz Khalifa
# Titulo : Black And Yellow
# Ano : 2010
# Mes : 10
# Pontos : 38
# Peak : 100
# Semanas : 25
#
# SongID:  Bottoms UpTrey Songz Featuring Nicki Minaj
# Artista : Trey Songz Featuring Nicki Minaj
# Titulo : Bottoms Up
# Ano : 2010
# Mes : 10
# Pontos : 445
# Peak : 95
# Semanas : 26
#
# SongID:  Break My BankNew Boyz Featuring Iyaz
# Artista : New Boyz Featuring Iyaz
# Titulo : Break My Bank
# Ano : 2010
# Mes : 10
# Pontos : 36
# Peak : 33
# Semanas : 11
#
# SongID:  BreakevenThe Script
# Artista : The Script
# Titulo : Breakeven
# Ano : 2010
# Mes : 10
# Pontos : 102
# Peak : 89
# Semanas : 43
#
# SongID:  Bridge Over Troubled WaterGlee Cast
# Artista : Glee Cast
# Titulo : Bridge Over Troubled Water
# Ano : 2010
# Mes : 10
# Pontos : 28
# Peak : 28
# Semanas : 1
#
# SongID:  California GurlsKaty Perry Featuring Snoop Dogg
# Artista : Katy Perry Featuring Snoop Dogg
# Titulo : California Gurls
# Ano : 2010
# Mes : 10
# Pontos : 406
# Peak : 100
# Semanas : 27
#
# SongID:  Can't Be FriendsTrey Songz
# Artista : Trey Songz
# Titulo : Can't Be Friends
# Ano : 2010
# Mes : 10
# Pontos : 178
# Peak : 58
# Semanas : 20
#
# SongID:  Check It Outwill.i.am & Nicki Minaj
# Artista : will.i.am & Nicki Minaj
# Titulo : Check It Out
# Ano : 2010
# Mes : 10
# Pontos : 294
# Peak : 77
# Semanas : 15
#
# SongID:  Club Can't Handle MeFlo Rida Featuring David Guetta
# Artista : Flo Rida Featuring David Guetta
# Titulo : Club Can't Handle Me
# Ano : 2010
# Mes : 10
# Pontos : 458
# Peak : 92
# Semanas : 29
#
# SongID:  Come Back SongDarius Rucker
# Artista : Darius Rucker
# Titulo : Come Back Song
# Ano : 2010
# Mes : 10
# Pontos : 266
# Peak : 64
# Semanas : 20
#
# SongID:  Cooler Than MeMike Posner
# Artista : Mike Posner
# Titulo : Cooler Than Me
# Ano : 2010
# Mes : 10
# Pontos : 410
# Peak : 95
# Semanas : 29
#
# SongID:  DeucesChris Brown Featuring Tyga & Kevin McCall
# Artista : Chris Brown Featuring Tyga & Kevin McCall
# Titulo : Deuces
# Ano : 2010
# Mes : 10
# Pontos : 424
# Peak : 87
# Semanas : 27
#
# SongID:  DJ Got Us Fallin' In LoveUsher Featuring Pitbull
# Artista : Usher Featuring Pitbull
# Titulo : DJ Got Us Fallin' In Love
# Ano : 2010
# Mes : 10
# Pontos : 481
# Peak : 97
# Semanas : 34
#
# SongID:  Dog Days Are OverFlorence + The Machine
# Artista : Florence + The Machine
# Titulo : Dog Days Are Over
# Ano : 2010
# Mes : 10
# Pontos : 134
# Peak : 80
# Semanas : 20
#
# SongID:  Don't Go Breaking My HeartGlee Cast
# Artista : Glee Cast
# Titulo : Don't Go Breaking My Heart
# Ano : 2010
# Mes : 10
# Pontos : 51
# Peak : 51
# Semanas : 1
#
# SongID:  DynamiteTaio Cruz
# Artista : Taio Cruz
# Titulo : Dynamite
# Ano : 2010
# Mes : 10
# Pontos : 473
# Peak : 99
# Semanas : 47
#
# SongID:  Empire State Of MindGlee Cast
# Artista : Glee Cast
# Titulo : Empire State Of Mind
# Ano : 2010
# Mes : 10
# Pontos : 87
# Peak : 80
# Semanas : 2
#
# SongID:  Erase MeKid Cudi Featuring Kanye West
# Artista : Kid Cudi Featuring Kanye West
# Titulo : Erase Me
# Ano : 2010
# Mes : 10
# Pontos : 27
# Peak : 79
# Semanas : 5
#
# SongID:  F**k You! (Forget You)Cee Lo Green
# Artista : Cee Lo Green
# Titulo : F**k You! (Forget You)
# Ano : 2010
# Mes : 10
# Pontos : 387
# Peak : 99
# Semanas : 48
#
# SongID:  FancyDrake Featuring T.I. & Swizz Beatz
# Artista : Drake Featuring T.I. & Swizz Beatz
# Titulo : Fancy
# Ano : 2010
# Mes : 10
# Pontos : 349
# Peak : 76
# Semanas : 20
#
# SongID:  Farmer's DaughterRodney Atkins
# Artista : Rodney Atkins
# Titulo : Farmer's Daughter
# Ano : 2010
# Mes : 10
# Pontos : 223
# Peak : 54
# Semanas : 21
#
# SongID:  Find Your LoveDrake
# Artista : Drake
# Titulo : Find Your Love
# Ano : 2010
# Mes : 10
# Pontos : 121
# Peak : 96
# Semanas : 21
#
# SongID:  FreeZac Brown Band
# Artista : Zac Brown Band
# Titulo : Free
# Ano : 2010
# Mes : 10
# Pontos : 42
# Peak : 67
# Semanas : 19
#
# SongID:  Glitter In The AirP!nk
# Artista : P!nk
# Titulo : Glitter In The Air
# Ano : 2010
# Mes : 10
# Pontos : 8
# Peak : 83
# Semanas : 18
#
# SongID:  GonorrheaLil Wayne Featuring Drake
# Artista : Lil Wayne Featuring Drake
# Titulo : Gonorrhea
# Ano : 2010
# Mes : 10
# Pontos : 126
# Peak : 84
# Semanas : 3
#
# SongID:  Got Your BackT.I. Featuring Keri Hilson
# Artista : T.I. Featuring Keri Hilson
# Titulo : Got Your Back
# Ano : 2010
# Mes : 10
# Pontos : 109
# Peak : 63
# Semanas : 20
#
# SongID:  GrenadeBruno Mars
# Artista : Bruno Mars
# Titulo : Grenade
# Ano : 2010
# Mes : 10
# Pontos : 55
# Peak : 100
# Semanas : 36
#
# SongID:  Half Of My HeartJohn Mayer
# Artista : John Mayer
# Titulo : Half Of My Heart
# Ano : 2010
# Mes : 10
# Pontos : 134
# Peak : 76
# Semanas : 20
#
# SongID:  Happy Days Are Here Again / Get HappyGlee Cast
# Artista : Glee Cast
# Titulo : Happy Days Are Here Again / Get Happy
# Ano : 2010
# Mes : 10
# Pontos : 53
# Peak : 53
# Semanas : 1
#
# SongID:  Hey Baby (Drop It To The Floor)Pitbull Featuring T-Pain
# Artista : Pitbull Featuring T-Pain
# Titulo : Hey Baby (Drop It To The Floor)
# Ano : 2010
# Mes : 10
# Pontos : 151
# Peak : 94
# Semanas : 31
#
# SongID:  Hey, Soul SisterTrain
# Artista : Train
# Titulo : Hey, Soul Sister
# Ano : 2010
# Mes : 10
# Pontos : 232
# Peak : 98
# Semanas : 54
#
# SongID:  Hold You (Hold Yuh)Gyptian
# Artista : Gyptian
# Titulo : Hold You (Hold Yuh)
# Ano : 2010
# Mes : 10
# Pontos : 9
# Peak : 24
# Semanas : 15
#
# SongID:  Holding You Down (Goin In Circles)Jazmine Sullivan
# Artista : Jazmine Sullivan
# Titulo : Holding You Down (Goin In Circles)
# Ano : 2010
# Mes : 10
# Pontos : 176
# Peak : 41
# Semanas : 12
#
# SongID:  Hope She Cheats On You (With A Basketball Player)Marsha Ambrosius
# Artista : Marsha Ambrosius
# Titulo : Hope She Cheats On You (With A Basketball Player)
# Ano : 2010
# Mes : 10
# Pontos : 13
# Peak : 13
# Semanas : 1
#
# SongID:  Hot TottieUsher Featuring Jay-Z
# Artista : Usher Featuring Jay-Z
# Titulo : Hot Tottie
# Ano : 2010
# Mes : 10
# Pontos : 380
# Peak : 80
# Semanas : 16
#
# SongID:  I Am Not A Human BeingLil Wayne
# Artista : Lil Wayne
# Titulo : I Am Not A Human Being
# Ano : 2010
# Mes : 10
# Pontos : 36
# Peak : 36
# Semanas : 1
#
# SongID:  I Like ItEnrique Iglesias Featuring Pitbull
# Artista : Enrique Iglesias Featuring Pitbull
# Titulo : I Like It
# Ano : 2010
# Mes : 10
# Pontos : 456
# Peak : 97
# Semanas : 38
#
# SongID:  I Look To YouGlee Cast
# Artista : Glee Cast
# Titulo : I Look To You
# Ano : 2010
# Mes : 10
# Pontos : 27
# Peak : 27
# Semanas : 1
#
# SongID:  I Want To Hold Your HandGlee Cast
# Artista : Glee Cast
# Titulo : I Want To Hold Your Hand
# Ano : 2010
# Mes : 10
# Pontos : 65
# Peak : 65
# Semanas : 1
#
# SongID:  If I Die YoungThe Band Perry
# Artista : The Band Perry
# Titulo : If I Die Young
# Ano : 2010
# Mes : 10
# Pontos : 337
# Peak : 87
# Semanas : 53
#
# SongID:  If I Had YouAdam Lambert
# Artista : Adam Lambert
# Titulo : If I Had You
# Ano : 2010
# Mes : 10
# Pontos : 321
# Peak : 71
# Semanas : 20
#
# SongID:  If It's LoveTrain
# Artista : Train
# Titulo : If It's Love
# Ano : 2010
# Mes : 10
# Pontos : 276
# Peak : 67
# Semanas : 20
#
# SongID:  I'm A Slave 4 UGlee Cast
# Artista : Glee Cast
# Titulo : I'm A Slave 4 U
# Ano : 2010
# Mes : 10
# Pontos : 49
# Peak : 49
# Semanas : 1
#
# SongID:  Just A DreamNelly
# Artista : Nelly
# Titulo : Just A Dream
# Ano : 2010
# Mes : 10
# Pontos : 480
# Peak : 98
# Semanas : 28
#
# SongID:  Just The Way You AreBruno Mars
# Artista : Bruno Mars
# Titulo : Just The Way You Are
# Ano : 2010
# Mes : 10
# Pontos : 499
# Peak : 100
# Semanas : 48
#
# SongID:  King Of AnythingSara Bareilles
# Artista : Sara Bareilles
# Titulo : King Of Anything
# Ano : 2010
# Mes : 10
# Pontos : 302
# Peak : 69
# Semanas : 22
#
# SongID:  La La LaAuburn Featuring Iyaz
# Artista : Auburn Featuring Iyaz
# Titulo : La La La
# Ano : 2010
# Mes : 10
# Pontos : 110
# Peak : 50
# Semanas : 13
#
# SongID:  Le Jazz HotGlee Cast
# Artista : Glee Cast
# Titulo : Le Jazz Hot
# Ano : 2010
# Mes : 10
# Pontos : 7
# Peak : 7
# Semanas : 1
#
# SongID:  Letting Go (Dutty Love)Sean Kingston Featuring Nicki Minaj
# Artista : Sean Kingston Featuring Nicki Minaj
# Titulo : Letting Go (Dutty Love)
# Ano : 2010
# Mes : 10
# Pontos : 305
# Peak : 65
# Semanas : 20
#
# SongID:  Like A G6Far*East Movement Featuring Cataracs & Dev
# Artista : Far*East Movement Featuring Cataracs & Dev
# Titulo : Like A G6
# Ano : 2010
# Mes : 10
# Pontos : 484
# Peak : 100
# Semanas : 26
#
# SongID:  Like We Used ToA Rocket To The Moon
# Artista : A Rocket To The Moon
# Titulo : Like We Used To
# Ano : 2010
# Mes : 10
# Pontos : 10
# Peak : 10
# Semanas : 1
#
# SongID:  ListenGlee Cast
# Artista : Glee Cast
# Titulo : Listen
# Ano : 2010
# Mes : 10
# Pontos : 63
# Peak : 63
# Semanas : 1
#
# SongID:  Little Lion ManMumford & Sons
# Artista : Mumford & Sons
# Titulo : Little Lion Man
# Ano : 2010
# Mes : 10
# Pontos : 155
# Peak : 56
# Semanas : 22
#
# SongID:  Little MissSugarland
# Artista : Sugarland
# Titulo : Little Miss
# Ano : 2010
# Mes : 10
# Pontos : 21
# Peak : 30
# Semanas : 14
#
# SongID:  Little White ChurchLittle Big Town
# Artista : Little Big Town
# Titulo : Little White Church
# Ano : 2010
# Mes : 10
# Pontos : 117
# Peak : 42
# Semanas : 20
#
# SongID:  LocaShakira Featuring Dizzee Rascal
# Artista : Shakira Featuring Dizzee Rascal
# Titulo : Loca
# Ano : 2010
# Mes : 10
# Pontos : 20
# Peak : 69
# Semanas : 11
#
# SongID:  Losing My ReligionGlee Cast
# Artista : Glee Cast
# Titulo : Losing My Religion
# Ano : 2010
# Mes : 10
# Pontos : 41
# Peak : 41
# Semanas : 1
#
# SongID:  Love All Over MeMonica
# Artista : Monica
# Titulo : Love All Over Me
# Ano : 2010
# Mes : 10
# Pontos : 173
# Peak : 43
# Semanas : 17
#
# SongID:  Love Like CrazyLee Brice
# Artista : Lee Brice
# Titulo : Love Like Crazy
# Ano : 2010
# Mes : 10
# Pontos : 32
# Peak : 56
# Semanas : 20
#
# SongID:  Love Like WoeThe Ready Set
# Artista : The Ready Set
# Titulo : Love Like Woe
# Ano : 2010
# Mes : 10
# Pontos : 278
# Peak : 74
# Semanas : 21
#
# SongID:  Love The Way You LieEminem Featuring Rihanna
# Artista : Eminem Featuring Rihanna
# Titulo : Love The Way You Lie
# Ano : 2010
# Mes : 10
# Pontos : 471
# Peak : 100
# Semanas : 29
#
# SongID:  Loving You No MoreDiddy - Dirty Money Featuring Drake
# Artista : Diddy - Dirty Money Featuring Drake
# Titulo : Loving You No More
# Ano : 2010
# Mes : 10
# Pontos : 10
# Peak : 10
# Semanas : 2
#
# SongID:  LuckyGlee Cast
# Artista : Glee Cast
# Titulo : Lucky
# Ano : 2010
# Mes : 10
# Pontos : 74
# Peak : 74
# Semanas : 1
#
# SongID:  MagicB.o.B Featuring Rivers Cuomo
# Artista : B.o.B Featuring Rivers Cuomo
# Titulo : Magic
# Ano : 2010
# Mes : 10
# Pontos : 376
# Peak : 91
# Semanas : 20
#
# SongID:  Mama's SongCarrie Underwood
# Artista : Carrie Underwood
# Titulo : Mama's Song
# Ano : 2010
# Mes : 10
# Pontos : 71
# Peak : 45
# Semanas : 19
#
# SongID:  Me Against The MusicGlee Cast
# Artista : Glee Cast
# Titulo : Me Against The Music
# Ano : 2010
# Mes : 10
# Pontos : 45
# Peak : 45
# Semanas : 1
#
# SongID:  MemoriesDavid Guetta Featuring Kid Cudi
# Artista : David Guetta Featuring Kid Cudi
# Titulo : Memories
# Ano : 2010
# Mes : 10
# Pontos : 35
# Peak : 55
# Semanas : 18
#
# SongID:  MineTaylor Swift
# Artista : Taylor Swift
# Titulo : Mine
# Ano : 2010
# Mes : 10
# Pontos : 442
# Peak : 98
# Semanas : 23
#
# SongID:  MiseryMaroon 5
# Artista : Maroon 5
# Titulo : Misery
# Ano : 2010
# Mes : 10
# Pontos : 401
# Peak : 87
# Semanas : 20
#
# SongID:  Miss MeDrake Featuring Lil Wayne
# Artista : Drake Featuring Lil Wayne
# Titulo : Miss Me
# Ano : 2010
# Mes : 10
# Pontos : 209
# Peak : 86
# Semanas : 20
#
# SongID:  Move That BodyNelly Featuring T-Pain & Akon
# Artista : Nelly Featuring T-Pain & Akon
# Titulo : Move That Body
# Ano : 2010
# Mes : 10
# Pontos : 47
# Peak : 47
# Semanas : 1
#
# SongID:  My Kinda PartyJason Aldean
# Artista : Jason Aldean
# Titulo : My Kinda Party
# Ano : 2010
# Mes : 10
# Pontos : 201
# Peak : 62
# Semanas : 20
#
# SongID:  Na Na Na (Na Na Na Na Na Na Na Na Na)My Chemical Romance
# Artista : My Chemical Romance
# Titulo : Na Na Na (Na Na Na Na Na Na Na Na Na)
# Ano : 2010
# Mes : 10
# Pontos : 24
# Peak : 24
# Semanas : 1
#
# SongID:  Need You NowLady Antebellum
# Artista : Lady Antebellum
# Titulo : Need You Now
# Ano : 2010
# Mes : 10
# Pontos : 162
# Peak : 99
# Semanas : 60
#
# SongID:  No HandsWaka Flocka Flame Featuring Roscoe Dash & Wale
# Artista : Waka Flocka Flame Featuring Roscoe Dash & Wale
# Titulo : No Hands
# Ano : 2010
# Mes : 10
# Pontos : 320
# Peak : 88
# Semanas : 32
#
# SongID:  No LoveEminem Featuring Lil Wayne
# Artista : Eminem Featuring Lil Wayne
# Titulo : No Love
# Ano : 2010
# Mes : 10
# Pontos : 92
# Peak : 78
# Semanas : 20
#
# SongID:  Not AfraidEminem
# Artista : Eminem
# Titulo : Not Afraid
# Ano : 2010
# Mes : 10
# Pontos : 390
# Peak : 100
# Semanas : 25
#
# SongID:  OMGUsher Featuring will.i.am
# Artista : Usher Featuring will.i.am
# Titulo : OMG
# Ano : 2010
# Mes : 10
# Pontos : 332
# Peak : 100
# Semanas : 30
#
# SongID:  One Of UsGlee Cast
# Artista : Glee Cast
# Titulo : One Of Us
# Ano : 2010
# Mes : 10
# Pontos : 64
# Peak : 64
# Semanas : 1
#
# SongID:  Only Girl (In The World)Rihanna
# Artista : Rihanna
# Titulo : Only Girl (In The World)
# Ano : 2010
# Mes : 10
# Pontos : 476
# Peak : 100
# Semanas : 27
#
# SongID:  Only PrettierMiranda Lambert
# Artista : Miranda Lambert
# Titulo : Only Prettier
# Ano : 2010
# Mes : 10
# Pontos : 65
# Peak : 40
# Semanas : 19
#
# SongID:  Only The Good Die YoungGlee Cast
# Artista : Glee Cast
# Titulo : Only The Good Die Young
# Ano : 2010
# Mes : 10
# Pontos : 51
# Peak : 51
# Semanas : 1
#
# SongID:  Our Kind Of LoveLady Antebellum
# Artista : Lady Antebellum
# Titulo : Our Kind Of Love
# Ano : 2010
# Mes : 10
# Pontos : 162
# Peak : 50
# Semanas : 20
#
# SongID:  Papa Can You Hear Me?Glee Cast
# Artista : Glee Cast
# Titulo : Papa Can You Hear Me?
# Ano : 2010
# Mes : 10
# Pontos : 36
# Peak : 36
# Semanas : 1
#
# SongID:  Please Don't GoMike Posner
# Artista : Mike Posner
# Titulo : Please Don't Go
# Ano : 2010
# Mes : 10
# Pontos : 153
# Peak : 85
# Semanas : 20
#
# SongID:  POWERKanye West
# Artista : Kanye West
# Titulo : POWER
# Ano : 2010
# Mes : 10
# Pontos : 52
# Peak : 79
# Semanas : 16
#
# SongID:  Pretty Boy SwagSoulja Boy Tell'em
# Artista : Soulja Boy Tell'em
# Titulo : Pretty Boy Swag
# Ano : 2010
# Mes : 10
# Pontos : 50
# Peak : 67
# Semanas : 16
#
# SongID:  Pretty Good At Drinkin' BeerBilly Currington
# Artista : Billy Currington
# Titulo : Pretty Good At Drinkin' Beer
# Ano : 2010
# Mes : 10
# Pontos : 152
# Peak : 60
# Semanas : 20
#
# SongID:  Put You In A SongKeith Urban
# Artista : Keith Urban
# Titulo : Put You In A Song
# Ano : 2010
# Mes : 10
# Pontos : 40
# Peak : 48
# Semanas : 20
#
# SongID:  RadioactiveKings Of Leon
# Artista : Kings Of Leon
# Titulo : Radioactive
# Ano : 2010
# Mes : 10
# Pontos : 70
# Peak : 64
# Semanas : 5
#
# SongID:  Raise Your GlassP!nk
# Artista : P!nk
# Titulo : Raise Your Glass
# Ano : 2010
# Mes : 10
# Pontos : 140
# Peak : 100
# Semanas : 30
#
# SongID:  Rhythm of LovePlain White T's
# Artista : Plain White T's
# Titulo : Rhythm of Love
# Ano : 2010
# Mes : 10
# Pontos : 34
# Peak : 63
# Semanas : 21
#
# SongID:  Ridin' SoloJason Derulo
# Artista : Jason Derulo
# Titulo : Ridin' Solo
# Ano : 2010
# Mes : 10
# Pontos : 262
# Peak : 92
# Semanas : 28
#
# SongID:  Right Above ItLil Wayne Featuring Drake
# Artista : Lil Wayne Featuring Drake
# Titulo : Right Above It
# Ano : 2010
# Mes : 10
# Pontos : 359
# Peak : 95
# Semanas : 24
#
# SongID:  Right Thru MeNicki Minaj
# Artista : Nicki Minaj
# Titulo : Right Thru Me
# Ano : 2010
# Mes : 10
# Pontos : 81
# Peak : 75
# Semanas : 19
#
# SongID:  River Deep, Mountain HighGlee Cast
# Artista : Glee Cast
# Titulo : River Deep, Mountain High
# Ano : 2010
# Mes : 10
# Pontos : 60
# Peak : 60
# Semanas : 1
#
# SongID:  Roll With ItEaston Corbin
# Artista : Easton Corbin
# Titulo : Roll With It
# Ano : 2010
# Mes : 10
# Pontos : 216
# Peak : 46
# Semanas : 19
#
# SongID:  Round & RoundSelena Gomez & The Scene
# Artista : Selena Gomez & The Scene
# Titulo : Round & Round
# Ano : 2010
# Mes : 10
# Pontos : 30
# Peak : 77
# Semanas : 14
#
# SongID:  RunawayKanye West Featuring Pusha T
# Artista : Kanye West Featuring Pusha T
# Titulo : Runaway
# Ano : 2010
# Mes : 10
# Pontos : 152
# Peak : 89
# Semanas : 13
#
# SongID:  SecretsOneRepublic
# Artista : OneRepublic
# Titulo : Secrets
# Ano : 2010
# Mes : 10
# Pontos : 381
# Peak : 80
# Semanas : 33
#
# SongID:  SeptemberDaughtry
# Artista : Daughtry
# Titulo : September
# Ano : 2010
# Mes : 10
# Pontos : 296
# Peak : 65
# Semanas : 20
#
# SongID:  ShakeJesse McCartney
# Artista : Jesse McCartney
# Titulo : Shake
# Ano : 2010
# Mes : 10
# Pontos : 34
# Peak : 47
# Semanas : 12
#
# SongID:  Sing!Glee Cast
# Artista : Glee Cast
# Titulo : Sing!
# Ano : 2010
# Mes : 10
# Pontos : 14
# Peak : 14
# Semanas : 1
#
# SongID:  SmileUncle Kracker
# Artista : Uncle Kracker
# Titulo : Smile
# Ano : 2010
# Mes : 10
# Pontos : 53
# Peak : 70
# Semanas : 33
#
# SongID:  Smoke A Little SmokeEric Church
# Artista : Eric Church
# Titulo : Smoke A Little Smoke
# Ano : 2010
# Mes : 10
# Pontos : 16
# Peak : 23
# Semanas : 20
#
# SongID:  Somebody To LoveJustin Bieber Featuring Usher
# Artista : Justin Bieber Featuring Usher
# Titulo : Somebody To Love
# Ano : 2010
# Mes : 10
# Pontos : 11
# Peak : 86
# Semanas : 18
#
# SongID:  Speak NowTaylor Swift
# Artista : Taylor Swift
# Titulo : Speak Now
# Ano : 2010
# Mes : 10
# Pontos : 149
# Peak : 93
# Semanas : 3
#
# SongID:  Stereo LoveEdward Maya & Vika Jigulina
# Artista : Edward Maya & Vika Jigulina
# Titulo : Stereo Love
# Ano : 2010
# Mes : 10
# Pontos : 35
# Peak : 85
# Semanas : 28
#
# SongID:  StrongerGlee Cast
# Artista : Glee Cast
# Titulo : Stronger
# Ano : 2010
# Mes : 10
# Pontos : 48
# Peak : 48
# Semanas : 1
#
# SongID:  Stuck Like GlueSugarland
# Artista : Sugarland
# Titulo : Stuck Like Glue
# Ano : 2010
# Mes : 10
# Pontos : 373
# Peak : 84
# Semanas : 24
#
# SongID:  StutterMaroon 5
# Artista : Maroon 5
# Titulo : Stutter
# Ano : 2010
# Mes : 10
# Pontos : 17
# Peak : 17
# Semanas : 1
#
# SongID:  Take It OffKe$ha
# Artista : Ke$ha
# Titulo : Take It Off
# Ano : 2010
# Mes : 10
# Pontos : 435
# Peak : 93
# Semanas : 20
#
# SongID:  Teach Me How To DougieCali Swag District
# Artista : Cali Swag District
# Titulo : Teach Me How To Dougie
# Ano : 2010
# Mes : 10
# Pontos : 199
# Peak : 73
# Semanas : 20
#
# SongID:  Teenage DreamKaty Perry
# Artista : Katy Perry
# Titulo : Teenage Dream
# Ano : 2010
# Mes : 10
# Pontos : 485
# Peak : 100
# Semanas : 33
#
# SongID:  TelephoneGlee Cast
# Artista : Glee Cast
# Titulo : Telephone
# Ano : 2010
# Mes : 10
# Pontos : 78
# Peak : 78
# Semanas : 1
#
# SongID:  The Boys of FallKenny Chesney
# Artista : Kenny Chesney
# Titulo : The Boys of Fall
# Ano : 2010
# Mes : 10
# Pontos : 326
# Peak : 83
# Semanas : 18
#
# SongID:  The Breath You TakeGeorge Strait
# Artista : George Strait
# Titulo : The Breath You Take
# Ano : 2010
# Mes : 10
# Pontos : 101
# Peak : 38
# Semanas : 20
#
# SongID:  The CatalystLinkin Park
# Artista : Linkin Park
# Titulo : The Catalyst
# Ano : 2010
# Mes : 10
# Pontos : 120
# Peak : 74
# Semanas : 10
#
# SongID:  The Lazy SongBruno Mars
# Artista : Bruno Mars
# Titulo : The Lazy Song
# Ano : 2010
# Mes : 10
# Pontos : 19
# Peak : 97
# Semanas : 27
#
# SongID:  The Only ExceptionGlee Cast
# Artista : Glee Cast
# Titulo : The Only Exception
# Ano : 2010
# Mes : 10
# Pontos : 75
# Peak : 75
# Semanas : 1
#
# SongID:  The Only ExceptionParamore
# Artista : Paramore
# Titulo : The Only Exception
# Ano : 2010
# Mes : 10
# Pontos : 230
# Peak : 77
# Semanas : 20
#
# SongID:  This Ain't No Love SongTrace Adkins
# Artista : Trace Adkins
# Titulo : This Ain't No Love Song
# Ano : 2010
# Mes : 10
# Pontos : 1
# Peak : 13
# Semanas : 6
#
# SongID:  ThisDarius Rucker
# Artista : Darius Rucker
# Titulo : This
# Ano : 2010
# Mes : 10
# Pontos : 18
# Peak : 50
# Semanas : 20
#
# SongID:  Toot It And Boot ItYG
# Artista : YG
# Titulo : Toot It And Boot It
# Ano : 2010
# Mes : 10
# Pontos : 136
# Peak : 34
# Semanas : 11
#
# SongID:  ToxicGlee Cast
# Artista : Glee Cast
# Titulo : Toxic
# Ano : 2010
# Mes : 10
# Pontos : 85
# Peak : 85
# Semanas : 1
#
# SongID:  TrailerhoodToby Keith
# Artista : Toby Keith
# Titulo : Trailerhood
# Ano : 2010
# Mes : 10
# Pontos : 2
# Peak : 4
# Semanas : 4
#
# SongID:  Turn On The RadioReba
# Artista : Reba
# Titulo : Turn On The Radio
# Ano : 2010
# Mes : 10
# Pontos : 56
# Peak : 48
# Semanas : 18
#
# SongID:  U SmileJustin Bieber
# Artista : Justin Bieber
# Titulo : U Smile
# Ano : 2010
# Mes : 10
# Pontos : 6
# Peak : 74
# Semanas : 4
#
# SongID:  Waiting For The EndLinkin Park
# Artista : Linkin Park
# Titulo : Waiting For The End
# Ano : 2010
# Mes : 10
# Pontos : 11
# Peak : 59
# Semanas : 23
#
# SongID:  Waka Waka (This Time For Africa)Shakira Featuring Freshlyground
# Artista : Shakira Featuring Freshlyground
# Titulo : Waka Waka (This Time For Africa)
# Ano : 2010
# Mes : 10
# Pontos : 36
# Peak : 63
# Semanas : 18
#
# SongID:  Way Out HereJosh Thompson
# Artista : Josh Thompson
# Titulo : Way Out Here
# Ano : 2010
# Mes : 10
# Pontos : 60
# Peak : 16
# Semanas : 9
#
# SongID:  We No Speak AmericanoYolanda Be Cool & Dcup
# Artista : Yolanda Be Cool & Dcup
# Titulo : We No Speak Americano
# Ano : 2010
# Mes : 10
# Pontos : 197
# Peak : 72
# Semanas : 20
#
# SongID:  What I Did For LoveGlee Cast
# Artista : Glee Cast
# Titulo : What I Did For Love
# Ano : 2010
# Mes : 10
# Pontos : 50
# Peak : 50
# Semanas : 1
#
# SongID:  What's Wrong With ThemLil Wayne Featuring Nicki Minaj
# Artista : Lil Wayne Featuring Nicki Minaj
# Titulo : What's Wrong With Them
# Ano : 2010
# Mes : 10
# Pontos : 59
# Peak : 59
# Semanas : 1
#
# SongID:  Why WaitRascal Flatts
# Artista : Rascal Flatts
# Titulo : Why Wait
# Ano : 2010
# Mes : 10
# Pontos : 150
# Peak : 53
# Semanas : 20
#
# SongID:  Your LoveNicki Minaj
# Artista : Nicki Minaj
# Titulo : Your Love
# Ano : 2010
# Mes : 10
# Pontos : 199
# Peak : 87
# Semanas : 20

# %% [markdown]
# #### Ordenando o dicionario pelas músicas mais populares e usando a popularidade máxima atingida em uma semana como critério de desempate

# %%
items = sorted(contador.items(), key = lambda tup: (tup[1]["Pontos"], tup[1]["Peak"], tup[1]["Semanas"]), reverse=True)

# %% [markdown]
# #### Imprimindo as 15 primeiras para testar

# %%
#1 deve sempre se manter fixo enquanto 
for i in range(5): #varre as 5 mais tocadas
    for y in items[i][1]: #varre as diferentes categorias do dicionario (artista, titulo, pontos)
        print(items[i][1][y])
    print('')
# Out:
# Bruno Mars
# Just The Way You Are
# 2010
# 10
# 499
# 100
# 48
#
# Katy Perry
# Teenage Dream
# 2010
# 10
# 485
# 100
# 33
#
# Far*East Movement Featuring Cataracs & Dev
# Like A G6
# 2010
# 10
# 484
# 100
# 26
#
# Usher Featuring Pitbull
# DJ Got Us Fallin' In Love
# 2010
# 10
# 481
# 97
# 34
#
# Nelly
# Just A Dream
# 2010
# 10
# 480
# 98
# 28

# %% [markdown]
# #### Cria um dicionario mais organizado com as 100 mais tocadas no período especificado

# %%
#armazena as primeiras 100 entradas em um dicionário mais organizado
top = [dict() for x in range(100)] #cria uma lista de 100 dicionarios

for i in range(len(top)):
    for y in items[i][1]:
        top[i][y] = items[i][1][y]

# %%
for x in range(100):
    print(top[x]['Titulo'], ':', top[x]['Pontos'])
# Out:
# Just The Way You Are : 499
# Teenage Dream : 485
# Like A G6 : 484
# DJ Got Us Fallin' In Love : 481
# Just A Dream : 480
# Only Girl (In The World) : 476
# Dynamite : 473
# Love The Way You Lie : 471
# Club Can't Handle Me : 458
# I Like It : 456
# Bottoms Up : 445
# Mine : 442
# Take It Off : 435
# Deuces : 424
# Animal : 416
# Cooler Than Me : 410
# California Gurls : 406
# Misery : 401
# Airplanes : 394
# Not Afraid : 390
# F**k You! (Forget You) : 387
# Secrets : 381
# Hot Tottie : 380
# Magic : 376
# Stuck Like Glue : 373
# Right Above It : 359
# Fancy : 349
# If I Die Young : 337
# OMG : 332
# 2012 (It Ain't The End) : 331
# The Boys of Fall : 326
# If I Had You : 321
# No Hands : 320
# Letting Go (Dutty Love) : 305
# King Of Anything : 302
# September : 296
# Check It Out : 294
# Love Like Woe : 278
# If It's Love : 276
# Come Back Song : 266
# As She's Walking Away : 263
# Ridin' Solo : 262
# Hey, Soul Sister : 232
# The Only Exception : 230
# Farmer's Daughter : 223
# Roll With It : 216
# Miss Me : 209
# Billionaire : 203
# My Kinda Party : 201
# Your Love : 199
# Teach Me How To Dougie : 199
# All Over Me : 199
# We No Speak Americano : 197
# Can't Be Friends : 178
# Holding You Down (Goin In Circles) : 176
# Love All Over Me : 173
# Need You Now : 162
# Our Kind Of Love : 162
# Little Lion Man : 155
# Please Don't Go : 153
# Runaway : 152
# Pretty Good At Drinkin' Beer : 152
# Hey Baby (Drop It To The Floor) : 151
# Why Wait : 150
# Speak Now : 149
# Anything Like Me : 143
# Raise Your Glass : 140
# Toot It And Boot It : 136
# Dog Days Are Over : 134
# Half Of My Heart : 134
# Gonorrhea : 126
# Find Your Love : 121
# The Catalyst : 120
# Little White Church : 117
# All I Want Is You : 116
# A Year Without Rain : 114
# La La La : 110
# Got Your Back : 109
# B.M.F. (Blowin' Money Fast) : 106
# Breakeven : 102
# The Breath You Take : 101
# Back To December : 95
# No Love : 92
# Empire State Of Mind : 87
# Toxic : 85
# Right Thru Me : 81
# Telephone : 78
# All About Tonight : 76
# The Only Exception : 75
# Lucky : 74
# Billionaire : 73
# Mama's Song : 71
# Radioactive : 70
# I Want To Hold Your Hand : 65
# Only Prettier : 65
# One Of Us : 64
# Listen : 63
# River Deep, Mountain High : 60
# Way Out Here : 60
# What's Wrong With Them : 59

# %% [markdown]
# #### Testando como escrever e ler de arquivos binarios
# ##### Mostra como guardar os arquivos binarios, eles devem ser estruturados e entao salvas desse jeito

# %%
import pickle #modulo usado para serializar dados para o arquivo binario
import os

filename = 'teste.bin'
topBytes = []

if os.path.exists(filename): #confere se o arquivo existe
    with open(filename,'rb') as openfile:  #with automaticamente da um close() no final
        topBytes = pickle.load(openfile)


newData = top #Aqui vem a nova data que deve ser concatenada
        
topBytes = topBytes + newData #concatena o que ja tinha no arquivo binario com a nova data
with (open(filename, 'wb+')) as openfile: #abre o arquivo de teste no modo de leitura binaria 'wb' como openfile
    pickle.dump(topBytes, openfile)

# %%
with (open('teste.bin', 'rb')) as openfile:
    leitura = pickle.load(openfile)

# %%
for x in range(100):
    print(leitura[x]['Titulo'], ':', top[x]['Pontos'])
# Out:
# Hey, Soul Sister : 3623
# Need You Now : 3485
# Breakeven : 2679
# Airplanes : 2662
# OMG : 2620
# In My Head : 2592
# Dynamite : 2545
# Break Your Heart : 2507
# I Like It : 2469
# TiK ToK : 2441
# Telephone : 2405
# California Gurls : 2403
# Nothin' On You : 2319
# Cooler Than Me : 2279
# Bad Romance : 2261
# Love The Way You Lie : 2259
# Haven't Met You Yet : 2168
# Not Afraid : 2160
# Billionaire : 2121
# I Gotta Feeling : 2070
# DJ Got Us Fallin' In Love : 2041
# Imma Be : 2006
# Your Love Is My Drug : 2002
# Whataya Want From Me : 1955
# Teenage Dream : 1949
# Just The Way You Are : 1942
# BedRock : 1938
# Say Aah : 1917
# Rude Boy : 1913
# Bulletproof : 1859
# Ridin' Solo : 1825
# Alejandro : 1822
# Club Can't Handle Me : 1812
# Carry Out : 1802
# Find Your Love : 1758
# Sexy Chick : 1711
# Animal : 1678
# How Low : 1674
# Secrets : 1603
# Just A Dream : 1600
# Live Like We're Dying : 1596
# Baby : 1580
# Bottoms Up : 1573
# Mine : 1565
# Deuces : 1534
# All The Right Moves : 1528
# Like A G6 : 1519
# Stuck Like Glue : 1483
# Misery : 1460
# Over : 1447
# Young Forever : 1442
# My Chick Bad : 1436
# Replay : 1427
# According To You : 1417
# If I Die Young : 1375
# Take It Off : 1371
# Your Love : 1367
# Blah Blah Blah : 1335
# Empire State Of Mind : 1328
# Impossible : 1321
# Right Above It : 1282
# Only Girl (In The World) : 1281
# Magic : 1258
# Un-Thinkable (I'm Ready) : 1258
# Naturally : 1258
# All I Do Is Win : 1234
# I Made It (Cash Money Heroes) : 1226
# Down : 1216
# Tie Me Down : 1212
# There Goes My Baby : 1190
# My First Kiss : 1183
# F**k You! (Forget You) : 1175
# Hey Daddy (Daddy's Home) : 1170
# King Of Anything : 1149
# Hard : 1133
# Fireflies : 1131
# You Belong With Me : 1128
# Say Something : 1128
# Undo It : 1114
# Do You Remember : 1096
# The House That Built Me : 1082
# The Only Exception : 1059
# Rock That Body : 1052
# Whatcha Say : 1044
# No Hands : 1021
# Teach Me How To Dougie : 1018
# Letting Go (Dutty Love) : 992
# Eenie Meenie : 985
# Today Was A Fairytale : 980
# Two Is Better Than One : 978
# American Honey : 965
# Lover, Lover : 954
# If I Had You : 949
# Hot Tottie : 945
# Life After You : 940
# If It's Love : 935
# Miss Me : 925
# The Boys of Fall : 923
# Pray For You : 921
# Raise Your Glass : 908

# %% [markdown]
# #### Criando um arquivo de indice

# %%
filename = 'indices.bin'
fileBytes = []

if os.path.exists(filename): #confere se o arquivo existe
    with open(filename,'rb') as openfile:  #with automaticamente da um close() no final
        fileBytes = pickle.load(openfile)


newData = {'Ano': ano, 'Min': len(fileBytes) - 100, 'Max': len(fileBytes) - 1} #Aqui vem a nova data que deve ser concatenada
        
fileBytes.append(newData)#concatena o que ja tinha no arquivo binario com a nova data
with (open(filename, 'wb+')) as openfile: #abre o arquivo de teste no modo de leitura binaria 'wb' como openfile
    pickle.dump(fileBytes, openfile)

# %% [markdown]
# #### A partir daqui são apenas teste
# ##### (Na verão atual do github [25/10/2018] o arquivo teste.bin contem as top 100 de 1990,2000,2010 nesta ordem)

# %%
#Imprime as 5 mais populares de 2010
counter = 0
for i in range(len(leitura)):
    if counter < 5:
        print(leitura[i]['Titulo'], ':', leitura[i]['Artista'])
        counter += 1
# Out:
# Hey, Soul Sister : Train
# Need You Now : Lady Antebellum
# Breakeven : The Script
# Airplanes : B.o.B Featuring Hayley Williams
# OMG : Usher Featuring will.i.am

# %%
#imprime as 5 primeiras entradas do arquivo (as 5 mais tocadas de 1990)
print(leitura[0]['Titulo'], ':', leitura[0]['Artista'])
print(leitura[1]['Titulo'], ':', leitura[1]['Artista'])
print(leitura[2]['Titulo'], ':', leitura[2]['Artista'])
print(leitura[3]['Titulo'], ':', leitura[3]['Artista'])
print(leitura[4]['Titulo'], ':', leitura[4]['Artista'])
# Out:
# Hey, Soul Sister : Train
# Need You Now : Lady Antebellum
# Breakeven : The Script
# Airplanes : B.o.B Featuring Hayley Williams
# OMG : Usher Featuring will.i.am

# %% [markdown]
# Todo: Fazer um loop na 4a celula para que coloque no arquivo binario as 100 que mais se manteram relevantes por ano

# %%
print(len(topBytes))
# Out:
# {'Artista': 'Train', 'Titulo': 'Hey, Soul Sister', 'Ano': 2010, 'Pontos': 3623, 'Peak': 98, 'Semanas': 54}
